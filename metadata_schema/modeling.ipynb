# %% [markdown]
# # Formula Drift Data - Data Model

# %%
import erdantic as erd
from erdantic.examples.pydantic import Party
import driverSchemas,judgingSchemas,performanceSchemas


diagram = erd.create(driverSchemas,judgingSchemas,performanceSchemas)
diagram
# Out:
# EntityRelationshipDiagram(models=[PydanticModel(Car), PydanticModel(Driver), PydanticModel(DriverProfile), PydanticModel(Event), PydanticModel(Season), PydanticModel(Sponsor), PydanticModel(Sponsorship), PydanticModel(Team), PydanticModel(Track), PydanticModel(Judge), PydanticModel(JudgeCall), PydanticModel(Battle), PydanticModel(Qualifying), PydanticModel(Tandem)], edges=[Edge(source=PydanticModel(DriverProfile), source_field=<PydanticField: 'driverID', Driver>, target=PydanticModel(Driver)), Edge(source=PydanticModel(DriverProfile), source_field=<PydanticField: 'teamID', Team>, target=PydanticModel(Team)), Edge(source=PydanticModel(DriverProfile), source_field=<PydanticField: 'carID', Car>, target=PydanticModel(Car)), Edge(source=PydanticModel(Event), source_field=<PydanticField: 'trackID', Track>, target=PydanticModel(Track)), Edge(source=PydanticModel(Event), source_field=<PydanticField: 'seasonID', Season>, target=PydanticModel(Season)), Edge(source=PydanticModel(Event), source_
# ...
